# %% [markdown]
# # pyvista-wasm in Google Colaboratory
#
# This notebook demonstrates [pyvista-wasm](https://github.com/tkoyama010/pyvista-wasm) rendering inline in a Colab cell using the `ColabRenderer`, which embeds the visualization in a sandboxed `<iframe>`.
#
# Run all cells to render the Stanford Bunny mesh without any local setup.

# %%
# !pip install pyvista-wasm

# %%
import pyvista_wasm as pv
from pyvista_wasm import examples

plotter = pv.Plotter()
mesh = examples.download_bunny()
plotter.add_mesh(mesh)
plotter.show()
